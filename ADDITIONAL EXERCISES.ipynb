# %%
ENGINEER = "INOCENCIO"
STUDENT_ID = "TUPM-25-0351"
SEED_NUM = int(STUDENT_ID[-1])

Target_name = ENGINEER
redacted_name = ""

print(f"Original Surname: {Target_name}")

for char in Target_name:
    if char in "AEIOU":
        redacted_name += str(SEED_NUM)
    else:
        redacted_name += char

print(f"Redacted Output: {redacted_name}")
# Out:
# Original Surname: INOCENCIO
# Redacted Output: 1N1C1NC11

# %%
ENGINEER = "INOCENCIO"
STUDENT_ID = "TUPM-25-0351"
SEED_NUM = int(STUDENT_ID[-1])
first_letter = ENGINEER[0]
ascii_value = ord(first_letter)

total_loops = SEED_NUM * ascii_value

verification_hash = (ascii_value * SEED_NUM) - total_loops

print(f"Verification Hash: {verification_hash}")
print(f"ASCII Value of '{first_letter}: {ascii_value}")
print(f"Total loops: {total_loops}")
print(f"SEED_NUM {SEED_NUM}")
# Out:
# Verification Hash: 0
# ASCII Value of 'I: 73
# Total loops: 73
# SEED_NUM 1

# %%
correct_password = "GERBER FILES"
attempts = 3

print("--- LOCKED ---")

while True: 
    user_pass = input("Enter password: ")
    print(f" ACCESS GRANTED. WELCOME {ENGINEER}")
    print(f" Total attempts before success: {attempts}")
    break
else:
    print( "Access Denied. Try Again.")
print(" ASSESSMENT DATA FOR EXERCISE 3")
print(f"Correct Password Set: {correct_password}")
print(f"Attempts before Success: {attempts}")
# Out:
# --- LOCKED ---
#  ACCESS GRANTED. WELCOME INOCENCIO
#  Tptal attempts before success: 3
#  ASSESSMENT DATA FOR EXERCISE 3
# Correct Password Set: GERBER FILES
# Attempts before Success: 3
